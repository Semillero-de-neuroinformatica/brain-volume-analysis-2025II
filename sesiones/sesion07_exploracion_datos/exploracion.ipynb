# %%
# Análisis Exploratorio de Datos (EDA)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('volumenes_first.csv')
df.head()
# Out:
#   Subject Structure  Label  NumVoxels  Volume_mm3
# 0  sub-01    L_Thal     10        571  518.723389
# 1  sub-01    L_Caud     11        123  111.739014
# 2  sub-01    L_Puta     12        118  107.196777
# 3  sub-01    L_Pall     13         28   25.436523
# 4  sub-01    BrStem     16        923  838.496826

# %%
# Información general del dataset
print("=== INFORMACIÓN GENERAL ===")
print(f"Dimensiones del dataset: {df.shape}")
print(f"Columnas: {list(df.columns)}")
print("\nTipos de datos:")
print(df.dtypes)
print("\nValores faltantes:")
print(df.isnull().sum())
# Out:
# === INFORMACIÓN GENERAL ===
# Dimensiones del dataset: (299, 5)
# Columnas: ['Subject', 'Structure', 'Label', 'NumVoxels', 'Volume_mm3']
#
# Tipos de datos:
# Subject        object
# Structure      object
# Label           int64
# NumVoxels       int64
# Volume_mm3    float64
# dtype: object
#
# Valores faltantes:
# Subject       0
# Structure     0
# Label         0
# NumVoxels     0
# Volume_mm3    0
# dtype: int64

# %%
# Estadísticas descriptivas
print("=== ESTADÍSTICAS DESCRIPTIVAS ===")
df.describe()
# Out:
# === ESTADÍSTICAS DESCRIPTIVAS ===
#             Label     NumVoxels    Volume_mm3
# count  299.000000    299.000000    299.000000
# mean    31.230769    777.591973    706.401299
# std     18.953234   2909.195852   2642.851018
# min     10.000000      0.000000      0.000000
# 25%     13.000000     12.000000     10.901367
# 50%     18.000000     79.000000     71.767334
# 75%     51.000000    336.500000    305.692505
# max     54.000000  38448.000000  34927.980469
